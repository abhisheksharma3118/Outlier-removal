# %%
import os
import random
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
import gc
from scipy.stats import zscore

# %%
df_Xtrain = pd.read_csv('X_train.csv')
df_ytrain = pd.read_csv('y_train.csv')
df_Xtest = pd.read_csv('X_test.csv')

# %%
df_Xtest.head()
# Out:
#   row_id  series_id  measurement_number  orientation_X  orientation_Y  \
# 0    0_0          0                   0      -0.025773       -0.98864
# 1    0_1          0                   1      -0.025683       -0.98862
# 2    0_2          0                   2      -0.025617       -0.98861
# 3    0_3          0                   3      -0.025566       -0.98862
# 4    0_4          0                   4      -0.025548       -0.98866
#
#    orientation_Z  orientation_W  angular_velocity_X  angular_velocity_Y  \
# 0       -0.14801       0.003350           -0.006524           -0.001071
# 1       -0.14816       0.003439           -0.113960            0.083987
# 2       -0.14826       0.003571           -0.080518            0.114860
# 3       -0.14817       0.003609            0.070067            0.033820
# 4       -0.14792       0.003477            0.152050           -0.029016
#
#    angular_velocity_Z  linear_acceleration_X  linear_acceleration_Y  \
# 0           -0.027390                0.10043                 4.2061
# 1           -0.060590               -0.70889                 3.9905
# 2           -0.037177                1.45710                 2.2828
# 3           -0.035904                0.71096                 1.8582
# 4           -0.015314                3.39960                 2.7881
#
#    linear_acceleration_Z
# 0                -5.5439
# 1                -8.0273
# 2               -11.2990
# 3               -12.2270
# 4               -10.4100

# %%
df_ytrain.head()
# Out:
#    series_id  group_id        surface
# 0          0        13  fine_concrete
# 1          1        31       concrete
# 2          2        20       concrete
# 3          3        31       concrete
# 4          4        22     soft_tiles

# %%
df_Xtrain.tail()
# Out:
#           row_id  series_id  measurement_number  orientation_X  orientation_Y  \
# 487675  3809_123       3809                 123        0.62871       -0.76878
# 487676  3809_124       3809                 124        0.62884       -0.76868
# 487677  3809_125       3809                 125        0.62891       -0.76861
# 487678  3809_126       3809                 126        0.62903       -0.76850
# 487679  3809_127       3809                 127        0.62915       -0.76839
#
#         orientation_Z  orientation_W  angular_velocity_X  angular_velocity_Y  \
# 487675      -0.084391       0.081093            0.003167            0.093760
# 487676      -0.084365       0.081099            0.014994            0.032637
# 487677      -0.084345       0.081178           -0.031184           -0.003961
# 487678      -0.084414       0.081231           -0.069153            0.013229
# 487679      -0.084441       0.081284           -0.042769            0.034049
#
#         angular_velocity_Z  linear_acceleration_X  linear_acceleration_Y  \
# 487675            -0.14274                3.27180                 2.0115
# 487676            -0.13238                4.42750                 3.0696
# 487677            -0.13894                2.70480                 4.2622
# 487678            -0.13021                2.54100                 4.7130
# 487679            -0.12580                0.82391                 4.2751
#
#         linear_acceleration_Z
# 487675                -9.0063
# 487676                -8.1257
# 487677                -8.1443
# 487678                -9.4435
# 487679               -10.4980

# %%
robot_stats2 = ['row_id','measurement_number', 'orientation_X', 'orientation_Y', 'orientation_Z', 'orientation_W',
              'angular_velocity_X', 'angular_velocity_Y', 'angular_velocity_Z',	
              'linear_acceleration_X', 'linear_acceleration_Y', 'linear_acceleration_Z']

# %%
robot_stats = ['orientation_X', 'orientation_Y', 'orientation_Z', 'orientation_W',
              'angular_velocity_X', 'angular_velocity_Y', 'angular_velocity_Z',	
              'linear_acceleration_X', 'linear_acceleration_Y', 'linear_acceleration_Z']

# %%
le = LabelEncoder()
df_ytrain['surface'] = le.fit_transform(df_ytrain['surface'])
df_ytrain.head()
# Out:
#    series_id  group_id  surface
# 0          0        13        2
# 1          1        31        1
# 2          2        20        1
# 3          3        31        1
# 4          4        22        6

# %%
df = df_Xtrain.merge(df_ytrain, on = 'series_id', how = 'inner')
y_train = df.drop(df[robot_stats2],axis = 1)
y_train.head()
# Out:
#    series_id  group_id  surface
# 0          0        13        2
# 1          0        13        2
# 2          0        13        2
# 3          0        13        2
# 4          0        13        2

# %%
def Z_Score(df):
    score = df[robot_stats].apply(zscore)
    remove_above = score[(score < 3).all(axis = 1)]
    remove_below = remove_above[(-3 < remove_above).all(axis = 1)]
    X_train = pd.concat([pd.DataFrame(remove_below), df['series_id']] , axis=1)
    X_train.fillna(0, inplace = True)
    
    return (X_train)

# %%
X_train = Z_Score(df_Xtrain)
X_train.head()
# Out:
#    orientation_X  orientation_Y  orientation_Z  orientation_W  \
# 0      -1.079897      -1.001675      -1.107250      -0.979549
# 1      -1.079897      -1.001661      -1.107439      -0.979837
# 2      -1.079897      -1.001675      -1.107628      -0.979549
# 3      -1.079882      -1.001689      -1.107911      -0.979549
# 4      -1.079882      -1.001675      -1.107911      -0.979453
#
#    angular_velocity_X  angular_velocity_Y  angular_velocity_Z  \
# 0            0.912613            0.104012            0.087064
# 1            0.574656            0.243598            0.098489
# 2            0.060266            0.232265            0.057627
# 3           -0.112348            0.125292            0.044556
# 4            0.042096           -0.007735            0.106605
#
#    linear_acceleration_X  linear_acceleration_Y  linear_acceleration_Z  \
# 0              -0.469289              -0.366095              -0.136474
# 1               0.112621              -0.644872              -0.016840
# 2              -0.210398              -0.604780               0.224292
# 3               0.159072              -0.835100              -0.256952
# 4              -0.341586              -0.662395              -0.378203
#
#    series_id
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
X_test = Z_Score(df_Xtest)
X_test.head()
# Out:
#    orientation_X  orientation_Y  orientation_Z  orientation_W  \
# 0      -0.085968      -1.552497      -1.537093      -0.006672
# 1      -0.085834      -1.552469      -1.538475      -0.005791
# 2      -0.085736      -1.552455      -1.539397      -0.004479
# 3      -0.085660      -1.552469      -1.538568      -0.004109
# 4      -0.085633      -1.552525      -1.536263      -0.005412
#
#    angular_velocity_X  angular_velocity_Y  angular_velocity_Z  \
# 0           -0.060484           -0.164810            0.037262
# 1           -0.998919            0.786202           -0.104746
# 2           -0.706809            1.131384           -0.004601
# 3            0.608521            0.225300            0.000844
# 4            1.324627           -0.477250            0.088915
#
#    linear_acceleration_X  linear_acceleration_Y  linear_acceleration_Z  \
# 0              -0.013643               0.620373               1.361529
# 1              -0.455258               0.517448               0.475444
# 2               0.726640              -0.297790              -0.691909
# 3               0.319500              -0.500490              -1.023022
# 4               1.786588              -0.056565              -0.374711
#
#    series_id
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
folds = StratifiedKFold(n_splits=10, shuffle=True, random_state=60)
predicted = np.zeros((X_test.shape[0],9))
measured= np.zeros((X_train.shape[0]))
score = 0
for times, (trn_idx, val_idx) in enumerate(folds.split(X_train.values,y_train['surface'].values)):
    model = RandomForestClassifier(n_estimators=700, n_jobs = -1)
    model.fit(X_train.iloc[trn_idx],y_train['surface'][trn_idx])
    measured[val_idx] = model.predict(X_train.iloc[val_idx])
    predicted += model.predict_proba(X_test)/folds.n_splits
    score += model.score(X_train.iloc[val_idx],y_train['surface'][val_idx])
    print("Fold: {} score: {}".format(times,model.score(X_train.iloc[val_idx],y_train['surface'][val_idx])))
    
    gc.collect()
# Out:
# Fold: 0 score: 0.997970188423923
# Fold: 1 score: 0.9980111947183893
# Fold: 2 score: 0.997990567972114
# Fold: 3 score: 0.9981340988312487
# Fold: 4 score: 0.9982570538057742
# Fold: 5 score: 0.9978469488188977
# Fold: 6 score: 0.9986875833077002
# Fold: 7 score: 0.9985235312211628
# Fold: 8 score: 0.9981748831104913
# Fold: 9 score: 0.9981748831104913

# %%
print('Average score', score / folds.n_splits)
# Out:
# Average score 0.9981770933320193

# %%
confusion_matrix(measured,y_train['surface'])
# Out:
# array([[24151,     4,     0,     0,     1,     6,     9,    11,    46],
#        [    9, 99492,    16,     0,   134,    18,     6,    18,    74],
#        [    0,    20, 46422,     0,    39,     3,     0,     6,     1],
#        [    0,     0,     0,  2688,     0,     0,     0,     0,     0],
#        [    0,    43,     6,     0, 39219,    11,     1,     7,    11],
#        [    1,    47,     3,     0,     4, 93603,     3,    41,     3],
#        [    1,     6,     0,     0,     1,     4, 37967,     7,     4],
#        [   19,    31,    16,     0,     4,    39,    26, 65695,     3],
#        [   11,    69,     1,     0,    22,    12,     4,     7, 77554]],
#       dtype=int64)

# %%
Pred1 = le.inverse_transform(predicted.argmax(axis = 1))
Pred = pd.DataFrame(Pred1)
Pred[Pred.columns].nunique()
# Out:
# 0    9
# dtype: int64
